# %% [markdown]
# # Introduction

# %% [markdown]
# Google Trends gives us an estimate of search volume. Let's explore if search popularity relates to other kinds of data. Perhaps there are patterns in Google's search volume and the price of Bitcoin or a hot stock like Tesla. Perhaps search volume for the term "Unemployment Benefits" can tell us something about the actual unemployment rate?
#
# Data Sources: <br>
# <ul>
# <li> <a href="https://fred.stlouisfed.org/series/UNRATE/">Unemployment Rate from FRED</a></li>
# <li> <a href="https://trends.google.com/trends/explore">Google Trends</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/TSLA/history?p=TSLA">Yahoo Finance for Tesla Stock Price</a> </li>
# <li> <a href="https://finance.yahoo.com/quote/BTC-USD/history?p=BTC-USD">Yahoo Finance for Bitcoin Stock Price</a> </li>
# </ul>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the Data
#
# Download and add the .csv files to the same folder as your notebook.

# %%
df_tesla = pd.read_csv('/content/drive/MyDrive/google_trends_data_folder/TESLA Search Trend vs Price.csv')

df_btc_search = pd.read_csv('/content/drive/MyDrive/google_trends_data_folder/Bitcoin Search Trend.csv')
df_btc_price = pd.read_csv('/content/drive/MyDrive/google_trends_data_folder/Daily Bitcoin Price.csv')

df_unemployment = pd.read_csv('/content/drive/MyDrive/google_trends_data_folder/UE Benefits Search vs UE Rate 2004-19.csv')

# %% [markdown]
# # Data Exploration

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Tesla

# %% [markdown]
# `**Challenge**: <br>
# <ul>
# <li>What are the shapes of the dataframes? </li>
# <li>How many rows and columns? </li>
# <li>What are the column names? </li>
# <li>Complete the f-string to show the largest/smallest number in the search data column</li>
# <li>Try the <code>.describe()</code> function to see some useful descriptive statistics</li>
# <li>What is the periodicity of the time series data (daily, weekly, monthly)? </li>
# </ul>

# %%
# What are the shapes of the dataframes?
# How many rows and columns?
print(df_tesla.shape)
df_tesla.head()
# Out:
# (124, 3)
#         MONTH  TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# 0  2010-06-01                3           4.766
# 1  2010-07-01                3           3.988
# 2  2010-08-01                2           3.896
# 3  2010-09-01                2           4.082
# 4  2010-10-01                2           4.368

# %% [markdown]
# **Answer**: The df_tesla DataFrame has 124 rows and 3 columns: for the Month, the search popularity and the closing price of the Tesla stock.

# %%
# What are the column names?
df_tesla.columns
# Out:
# Index(['MONTH', 'TSLA_WEB_SEARCH', 'TSLA_USD_CLOSE'], dtype='object')

# %%
df_tesla.loc[123]
# Out:
# MONTH              2020-09-01
# TSLA_WEB_SEARCH            31
# TSLA_USD_CLOSE     407.339996
# Name: 123, dtype: object

# %%
# Complete the f-string to show the largest/smallest number in the search data column

print(f'Largest value for Tesla in Web Search: {df_tesla['TSLA_WEB_SEARCH'].max()}')
print(f'Smallest value for Tesla in Web Search: {df_tesla['TSLA_WEB_SEARCH'].min()}')
# Out:
# Largest value for Tesla in Web Search: 31
# Smallest value for Tesla in Web Search: 2

# %%
# Try the .describe() function to see some useful descriptive statistics
df_tesla.describe()
# Out:
#        TSLA_WEB_SEARCH  TSLA_USD_CLOSE
# count       124.000000      124.000000
# mean          8.725806       50.962145
# std           5.870332       65.908389
# min           2.000000        3.896000
# 25%           3.750000        7.352500
# 50%           8.000000       44.653000
# 75%          12.000000       58.991999
# max          31.000000      498.320007

# %%
#What is the periodicity of the time series data (daily, weekly, monthly)?
date_diffs = df_tesla.index.to_series().diff().value_counts()

print(date_diffs)
# Out:
# MONTH
# 31 days    72
# 30 days    41
# 28 days     7
# 29 days     3
# Name: count, dtype: int64

# %% [markdown]
# ### Unemployment Data

# %%
# What are the shapes of the dataframes?
# How many rows and columns?
print(df_unemployment.shape)
df_unemployment.head()
# Out:
# (181, 3)
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                      34     5.7
# 1  2004-02                      33     5.6
# 2  2004-03                      25     5.8
# 3  2004-04                      29     5.6
# 4  2004-05                      23     5.6

# %% [markdown]
# **Answer**: The unemployment DataFrame has 181 rows and 3 columns. As with Tesla, we have monthly data from 2004 onwards, organised in rows. Interestingly here, the largest value in the search column is 100.

# %%
# What are the column names?
df_unemployment.columns
# Out:
# Index(['MONTH', 'UE_BENEFITS_WEB_SEARCH', 'UNRATE'], dtype='object')

# %%
# Complete the f-string to show the largest/smallest number in the search data column
print('Largest value for "Unemployemnt Benefits" '
      f'in Web Search: {df_unemployment.UE_BENEFITS_WEB_SEARCH.max()}')
# Out:
# Largest value for "Unemployemnt Benefits" in Web Search: 100

# %%
# Try the .describe() function to see some useful descriptive statistics
df_unemployment.describe()
# Out:
#        UE_BENEFITS_WEB_SEARCH      UNRATE
# count              181.000000  181.000000
# mean                35.110497    6.217680
# std                 20.484925    1.891859
# min                 14.000000    3.700000
# 25%                 21.000000    4.700000
# 50%                 26.000000    5.400000
# 75%                 45.000000    7.800000
# max                100.000000   10.000000

# %% [markdown]
# ### Bitcoin

# %%
# What are the shapes of the dataframes?
# How many rows and columns?
print(df_btc_price.shape)
df_btc_price.head()
# Out:
# (2204, 3)
#          DATE       CLOSE      VOLUME
# 0  2014-09-17  457.334015  21056800.0
# 1  2014-09-18  424.440002  34483200.0
# 2  2014-09-19  394.795990  37919700.0
# 3  2014-09-20  408.903992  36863600.0
# 4  2014-09-21  398.821014  26580100.0

# %%
# What are the shapes of the dataframes?
# How many rows and columns?
print(df_btc_search.shape)
df_btc_search.head()
# Out:
# (73, 2)
#      MONTH  BTC_NEWS_SEARCH
# 0  2014-09                5
# 1  2014-10                4
# 2  2014-11                4
# 3  2014-12                4
# 4  2015-01                5

# %%
print(f'largest BTC News Search: {df_btc_search.BTC_NEWS_SEARCH.max()}')
# Out:
# largest BTC News Search: 100

# %% [markdown]
# **Answer**: With the Bitcoin data we see that we have two different .csv files. One of them has the day-by-day closing price and the trade volume of Bitcoin across 2204 rows. The other has the monthly search volume from Google Trends.

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Check for Missing Values

# %% [markdown]
# **Challenge**: Are there any missing values in any of the dataframes? If so, which row/rows have missing values? How many missing values are there?

# %%
print(f'Missing values for Tesla?: {df_tesla.isna().values.any()}')
print(f'Missing values for U/E?: {df_unemployment.isna().values.any()}')
print(f'Missing values for BTC Search?: {df_btc_search.isna().values.any()}')
# Out:
# Missing values for Tesla?: False
# Missing values for U/E?: False
# Missing values for BTC Search?: False

# %%
print(f'Missing values for BTC price?: {df_btc_price.isna().values.any()}')
# Out:
# Missing values for BTC price?: True

# %%
print(f'Number of missing values: {df_btc_price.isna().values.sum()}')
df_btc_price[df_btc_price.CLOSE.isna()]
# Out:
# Number of missing values: 2
#             DATE  CLOSE  VOLUME
# 2148  2020-08-04    NaN     NaN

# %% [markdown]
# **Answer**: For 3 of the DataFrames there are no missing values. I have verify this using the .isna() method. This will return a whole series of booleans, but we can chain .values.any() to see if any value in the series is True. However, for the Bitcoin price data, there seems to be a problem. There's a missing value somewhere. The number of missing values can be found by using .sum() to add up the number of occurrences of True in the series. This shows that there are 2 missing values.

# %% [markdown]
# **Challenge**: Remove any missing values that you found.

# %%
df_btc_price = df_btc_price.dropna()
df_btc_price.shape
# Out:
# (2203, 3)

# %% [markdown]
# ### Convert Strings to DateTime Objects

# %% [markdown]
# **Challenge**: Check the data type of the entries in the DataFrame MONTH or DATE columns. Convert any strings in to Datetime objects. Do this for all 4 DataFrames. Double check if your type conversion was successful.

# %%
print(type(df_tesla.MONTH[6]))                       # Checking the data type of the entries in the DataFrame of MONTH or DATE columns
df_tesla.MONTH = pd.to_datetime(df_tesla.MONTH)      # Converting any strings in to Datetime objects
type(df_tesla.MONTH[6])                              # checking if type conversion was successful or not.
# Out:
# <class 'str'>
# pandas._libs.tslibs.timestamps.Timestamp

# %%
print(type(df_unemployment.MONTH[6]))                              # Checking the data type of the entries in the DataFrame of MONTH or DATE columns
df_unemployment.MONTH = pd.to_datetime(df_unemployment.MONTH)      # Converting any strings in to Datetime objects
type(df_unemployment.MONTH[6])                                     # checking if type conversion was successful or not.
# Out:
# <class 'str'>
# pandas._libs.tslibs.timestamps.Timestamp

# %%
print(type(df_btc_price.DATE[6]))                                  # Checking the data type of the entries in the DataFrame of MONTH or DATE columns
df_btc_price.DATE = pd.to_datetime(df_btc_price.DATE)              # Converting any strings in to Datetime objects
type(df_btc_price.DATE[6])                                         # checking if type conversion was successful or not.
# Out:
# <class 'str'>
# pandas._libs.tslibs.timestamps.Timestamp

# %%
print(type(df_btc_search.MONTH[6]))                              # Checking the data type of the entries in the DataFrame of MONTH or DATE columns
df_btc_search.MONTH = pd.to_datetime(df_btc_search.MONTH)        # Converting any strings in to Datetime objects
type(df_btc_search.MONTH[6])                                     # checking if type conversion was successful or not.
# Out:
# <class 'str'>
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# **Answer**: All the date data in our columns are in the form of strings. To convert this into a Datetime object we have used the Pandas .to_datetime() function.

# %% [markdown]
# ### Converting from Daily to Monthly Data
#
# [Pandas .resample() documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) <br>

# %%
df_btc_monthly = df_btc_price.resample('M', on='DATE').last()
# Out:
# /tmp/ipykernel_3327/1678758910.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df_btc_monthly = df_btc_price.resample('M', on='DATE').last()

# %%
print(df_btc_monthly.shape)
df_btc_monthly.head()
# Out:
# (73, 2)
#                  CLOSE      VOLUME
# DATE
# 2014-09-30  386.944000  34707300.0
# 2014-10-31  338.321014  12545400.0
# 2014-11-30  378.046997   9194440.0
# 2014-12-31  320.192993  13942900.0
# 2015-01-31  217.464005  23348200.0

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Notebook Formatting & Style Helpers

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Create locators for ticks on the time axis
years = mdates.YearLocator()
month = mdates.MonthLocator()
years_fmt = mdates.DateFormatter('%Y')

# %%
# Register date converters to avoid warning messages

# %% [markdown]
# ### Tesla Stock Price v.s. Search Volume

# %% [markdown]
# **Challenge:** Plot the Tesla stock price against the Tesla search volume using a line chart and two different axes. Label one axis 'TSLA Stock Price' and the other 'Search Trend'.

# %%
ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH)

ax1.set_xlabel('Year')
ax1.set_ylabel('TSLA Stock Price')
ax2.set_ylabel('Search Trends')
# Out:
# Text(0, 0.5, 'Search Trends')

# %% [markdown]
# **Challenge**: Add colours to style the chart. This will help differentiate the two lines and the axis labels. Try using one of the blue [colour names](https://matplotlib.org/3.1.1/gallery/color/named_colors.html) for the search volume and a HEX code for a red colour for the stock price.
# <br>
# <br>
# Hint: you can colour both the [axis labels](https://matplotlib.org/3.3.2/api/text_api.html#matplotlib.text.Text) and the [lines](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D) on the chart using keyword arguments (kwargs).

# %%
ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color = 'g')
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color = 'b')

ax1.set_xlabel('Year')
ax1.set_ylabel('TSLA Stock Price', color = 'g')
ax2.set_ylabel('Search Trends', color = 'b')
# Out:
# Text(0, 0.5, 'Search Trends')

# %% [markdown]
# **Answer**: To create a line plot with two different y-axes we first have to get the current axis and make a copy of it using .twinx(). Then we can configure each axis separately and call .plot().

# %% [markdown]
# **Challenge**: Make the chart larger and easier to read.
# 1. Increase the figure size (e.g., to 14 by 8).
# 2. Increase the font sizes for the labels and the ticks on the x-axis to 14.
# 3. Rotate the text on the x-axis by 45 degrees.
# 4. Make the lines on the chart thicker.
# 5. Add a title that reads 'Tesla Web Search vs Price'
# 6. Keep the chart looking sharp by changing the dots-per-inch or [DPI value](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.figure.html).
# 7. Set minimum and maximum values for the y and x axis. Hint: check out methods like [set_xlim()](https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.axes.Axes.set_xlim.html).
# 8. Finally use [plt.show()](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.show.html) to display the chart below the cell instead of relying on the automatic notebook output.

# %%
plt.figure(figsize=(14,8), dpi=120) # increading figure size
plt.xticks(fontsize = 14, rotation=45) # increading xtick text(ex: 2010, 2012)


ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
plt.title('Tesla Web Search vs Price')

# Also, increase fontsize and linewidth for larger charts
ax1.set_xlabel('Year', fontsize = 14)
ax1.set_ylabel('TSLA Stock Price', color = 'g', fontsize = 14)
ax2.set_ylabel('Search Trends', color = 'b', fontsize = 14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])


ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color = 'g', linewidth=2)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color = 'b', linewidth=2)

# Displays chart explicitly
plt.show()

# %% [markdown]
# **Answer**: There's a couple of tweaks to the code going on here. First, we have used .figure() to increase the size and resolution of our chart. Since we now have a bigger chart, we should also increase the font size of our labels and the thickness of our lines. than we have added rotation of x ticks to 45 degree and by using .set_ylim() and .set_xlim() I have precise control over which data I want to show on the chart. I can either choose hard values like displaying the Tesla stock price between 0 and 600. Or I could use the .min() and .max() functions to help you work out the bounds for the chart as well.

# %% [markdown]
# How to add tick formatting for dates on the x-axis.

# %%
plt.figure(figsize=(14,8), dpi=120) # increading figure size
plt.xticks(fontsize = 14, rotation=45) # increading xtick text(ex: 2010, 2012)


ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
plt.title('Tesla Web Search vs Price')


# Also, increase fontsize and linewidth for larger charts
ax1.set_xlabel('Year', fontsize = 14)
ax1.set_ylabel('TSLA Stock Price', color = 'g', fontsize = 14)
ax2.set_ylabel('Search Trends', color = 'b', fontsize = 14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 600])
ax1.set_xlim([df_tesla.MONTH.min(), df_tesla.MONTH.max()])


ax1.plot(df_tesla.MONTH, df_tesla.TSLA_USD_CLOSE, color = 'g', linewidth=2)
ax2.plot(df_tesla.MONTH, df_tesla.TSLA_WEB_SEARCH, color = 'b', linewidth=2)

# using locators for ticks on the time axis
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(month)


# Displays chart explicitly
plt.show()

# %% [markdown]
# When we take a look at our chart, we can see the tick marks nicely. The tick marks also allow us to visually date that spike of interest in the middle of the chart - March 2016. This was when the Tesla Model 3 was unveiled. Also, we can clearly see that the most recent spikes in search coincide, not with the release of a new car, but the roaring stock price for the company!

# %% [markdown]
# ### Bitcoin (BTC) Price v.s. Search Volume

# %% [markdown]
# **Challenge**: Create the same chart for the Bitcoin Prices vs. Search volumes. <br>
# 1. Modify the chart title to read 'Bitcoin News Search vs Resampled Price' <br>
# 2. Change the y-axis label to 'BTC Price' <br>
# 3. Change the y- and x-axis limits to improve the appearance <br>
# 4. Investigate the [linestyles](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.plot.html ) to make the BTC price a dashed line <br>
# 5. Investigate the [marker types](https://matplotlib.org/3.2.1/api/markers_api.html) to make the search datapoints little circles <br>
# 6. Were big increases in searches for Bitcoin accompanied by big increases in the price?

# %%
plt.figure(figsize=(14,8), dpi=120) # increading figure size
plt.xticks(fontsize = 14, rotation=45) # increading xtick text(ex: 2010, 2012)


ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
plt.title('Bitcoin News Search vs Resampled Price')


# Also, increase fontsize and linewidth for larger charts
ax1.set_xlabel('Year', fontsize = 14)
ax1.set_ylabel('BTC Price', color = '#F08F2E', fontsize = 14)
ax2.set_ylabel('Search Trend', color = 'skyblue', fontsize = 14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([0, 15000])
ax1.set_xlim([df_btc_monthly.index.min(), df_btc_monthly.index.max()])

# Experiment with the linestyle and markers
ax1.plot(df_btc_monthly.index, df_btc_monthly.CLOSE, color = '#F08F2E', linewidth=3, linestyle='--')
ax2.plot(df_btc_monthly.index, df_btc_search.BTC_NEWS_SEARCH, color = 'skyblue', linewidth=3, marker='.', markersize=10)

# using locators for ticks on the time axis
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(month)


# Displays chart explicitly
plt.show()

# %% [markdown]
# **Answer**: What we see in the chart is that similar to Tesla, the crazy price movements in the beginning of 2018 are associated with very high search volumes. Everyone was talking about (and buying) Bitcoin in late 2017/early 2018 so search volumes were at a record high!  Interestingly, there was quite a huge spike in bitcoin prices in Q1 of 2019, but this time the increase in search volume was much less pronounced (perhaps because at this point everyone knew what Bitcoin was).

# %% [markdown]
# ### Unemployement Benefits Search vs. Actual Unemployment in the U.S.

# %% [markdown]
# **Challenge** Plot the search for "unemployment benefits" against the unemployment rate.
# 1. Change the title to: Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate <br>
# 2. Change the y-axis label to: FRED U/E Rate <br>
# 3. Change the axis limits <br>
# 4. Add a grey [grid](https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.grid.html) to the chart to better see the years and the U/E rate values. Use dashes for the line style<br>
# 5. Can you discern any seasonality in the searches? Is there a pattern?

# %%
plt.figure(figsize=(14,8), dpi=120) # increading figure size
plt.xticks(fontsize = 14, rotation=45) # increading xtick text(ex: 2010, 2012)
plt.yticks(fontsize=14)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')


# Also, increase fontsize and linewidth for larger charts
ax1.set_xlabel('Year', fontsize = 14)
ax1.set_ylabel('FRED U/E Rate', color = 'purple', fontsize = 14)
ax2.set_ylabel('Search Trend', color = 'skyblue', fontsize = 14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([3, 10.5])
ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])


# Show the grid lines as dark grey lines
ax1.grid(color='grey', linestyle='--')

# Experiment with the linestyle and markers
ax1.plot(df_unemployment.MONTH, df_unemployment.UNRATE, color = 'purple', linewidth=3, linestyle='--')
ax2.plot(df_unemployment.MONTH, df_unemployment.UE_BENEFITS_WEB_SEARCH, color = 'skyblue', linewidth=3)

# using locators for ticks on the time axis
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(month)


# Displays chart explicitly
plt.show()

# %% [markdown]
# **Answer**: Ok, so there are relatively few changes I had to make. Just the labels and the dataset we're using. we have used .grid() method to overlay a grid of dashed lines, Notice how we can now clearly see the vertical dashed lines line up with spikes in searches for "Unemployment benefits". Many of the spikes are at year-end - in December. This clearly shows that there is seasonality in the job market. Also we can see that the financial crisis in 2007/2008 caused a massive spike in unemployment. It took around 10 years (2007-2017) for the unemployment to reach the same level it had before the crisis. Interestingly the big spike in searches for Unemployment benefits at the end of 2013 was not accompanied by a big increase in the unemployment rate. Something else must have been going on around that time.

# %% [markdown]
# **Challenge**: Calculate the 3-month or 6-month rolling average for the web searches. Plot the 6-month rolling average search data against the actual unemployment. What do you see in the chart? Which line moves first?

# %%
plt.figure(figsize=(14,8), dpi=120) # increading figure size
plt.xticks(fontsize = 14, rotation=45) # increading xtick text(ex: 2010, 2012)
plt.yticks(fontsize=14)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate')


# Also, increase fontsize and linewidth for larger charts
ax1.set_xlabel('Year', fontsize = 14)
ax1.set_ylabel('FRED U/E Rate', color = 'purple', fontsize = 14)
ax2.set_ylabel('Search Trend', color = 'skyblue', fontsize = 14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([3, 10.5])
ax1.set_xlim([df_unemployment.MONTH.min(), df_unemployment.MONTH.max()])


# Show the grid lines as dark grey lines
ax1.grid(color='grey', linestyle='--')


# The window is number of observations that are averaged
roll_df = df_unemployment[['UE_BENEFITS_WEB_SEARCH', 'UNRATE']].rolling(window=6).mean()


# Experiment with the linestyle and markers
ax1.plot(df_unemployment.MONTH, roll_df.UNRATE, color = 'purple', linewidth=3, linestyle='--')
ax2.plot(df_unemployment.MONTH, roll_df.UE_BENEFITS_WEB_SEARCH, color = 'skyblue', linewidth=3)

# using locators for ticks on the time axis
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(month)



# Displays chart explicitly
plt.show()

# %% [markdown]
# **Answer**: What is this telling us? We see that searches for "Unemployment Benefits" happen before the actual official unemployment rate goes up. Similarly, the search popularity for the term goes down before the unemployment rate decreases. In other words, these searches seem to act as a leading economic indicator for the unemployment rate (which is a lagging indicator).

# %% [markdown]
# ### Including 2020 in Unemployment Charts

# %% [markdown]
# **Challenge**: Read the data in the 'UE Benefits Search vs UE Rate 2004-20.csv' into a DataFrame. Convert the MONTH column to Pandas Datetime objects and then plot the chart. What do you see?

# %%
df_ue_2020 = pd.read_csv('/content/drive/MyDrive/google_trends_data_folder/UE Benefits Search vs UE Rate 2004-20.csv')
df_ue_2020.head()
# Out:
#      MONTH  UE_BENEFITS_WEB_SEARCH  UNRATE
# 0  2004-01                       9     5.7
# 1  2004-02                       8     5.6
# 2  2004-03                       7     5.8
# 3  2004-04                       8     5.6
# 4  2004-05                       6     5.6

# %%
print(type(df_ue_2020.MONTH[3]))                       # Checking the data type of the entries in the DataFrame of MONTH or DATE columns
df_ue_2020.MONTH = pd.to_datetime(df_ue_2020.MONTH)      # Converting any strings in to Datetime objects
type(df_ue_2020.MONTH[6])                              # checking if type conversion was successful or not.
# Out:
# <class 'str'>
# pandas._libs.tslibs.timestamps.Timestamp

# %%
plt.figure(figsize=(14,8), dpi=120) # increading figure size
plt.xticks(fontsize = 14, rotation=45) # increading xtick text(ex: 2010, 2012)
plt.yticks(fontsize=14)

ax1 = plt.gca() # get current axes
ax2 = ax1.twinx() # create another axis that shares the same axis

# add styling
plt.title('Monthly Search of "Unemployment Benefits" in the U.S. vs the U/E Rate till 2020')


# Also, increase fontsize and linewidth for larger charts
ax1.set_xlabel('Year', fontsize = 14)
ax1.set_ylabel('FRED U/E Rate', color = 'purple', fontsize = 14)
ax2.set_ylabel('Search Trend', color = 'skyblue', fontsize = 14)

# Set the minimum and maximum values on the axes
ax1.set_ylim([3, 15])
ax1.set_xlim([df_ue_2020.MONTH.min(), df_ue_2020.MONTH.max()])


# Show the grid lines as dark grey lines
ax1.grid(color='grey', linestyle='--')

# Experiment with the linestyle and markers
ax1.plot(df_ue_2020.MONTH, df_ue_2020.UNRATE, color = 'purple', linewidth=3)
ax2.plot(df_ue_2020.MONTH, df_ue_2020.UE_BENEFITS_WEB_SEARCH, color = 'skyblue', linewidth=3)

# using locators for ticks on the time axis
ax1.xaxis.set_major_locator(years)
ax1.xaxis.set_major_formatter(years_fmt)
ax1.xaxis.set_minor_locator(month)


# Displays chart explicitly
plt.show()

# %% [markdown]
# **Answer**: What we see is not pretty. The US unemployment rate spiked to unprecedented levels during the COVID pandemic, dwarfing the levels seen during the financial crisis. Let's hope the recovery will be swifter this time.
#
# ---
